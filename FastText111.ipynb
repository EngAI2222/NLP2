# %%
from gensim.models import FastText

sentences = [
    "بسم الله الرحمن الرحيم",
    "الحمد لله رب العالمين",
    "الرحمن الرحيم",
    "مالك يوم الدين",
    "اياك نعبد واياك نستعين",
    "اهدنا الصراط المستقيم",
    "صراط الذين انعمت عليهم غير المغضوب عليهم ولا الضالين"
]
sentences = [s.split() for s in sentences]

model = FastText(sentences, vector_size=50, window=3, min_count=1)

print("Vector for 'نموذج':", model.wv["نموذج"])
# Out:
# Vector for 'نموذج': [ 1.2180947e-03 -2.5146028e-03  8.4583284e-05  2.7327463e-03
#   8.1945176e-04  2.9640130e-03 -1.6921067e-03 -1.4587971e-04
#  -7.3150089e-03 -5.7616044e-04 -1.5740495e-04  6.6308402e-03
#   1.8687627e-03  9.8334416e-04  2.8510448e-03 -2.0528077e-03
#   6.8664976e-04  1.7674246e-03 -2.2007881e-03 -2.9536691e-03
#  -3.1439702e-03  3.3367777e-03 -2.1754627e-03 -1.6012581e-04
#   1.6956261e-03  3.9905004e-04 -6.3669368e-06 -1.9661449e-03
#  -3.8852828e-04 -2.5846405e-04 -5.2238628e-03 -2.3651535e-04
#  -1.3638560e-03  9.7184983e-04 -2.4717930e-03  5.8413867e-04
#   3.5388817e-03 -6.5118121e-03 -9.7691442e-04  7.5568869e-03
#  -2.8215987e-03  4.4283322e-05  1.7751349e-03  1.8702511e-03
#   1.3538372e-03  9.3876012e-04  5.8143712e-03  8.5188309e-04
#  -1.1651339e-03 -1.9732853e-03]
